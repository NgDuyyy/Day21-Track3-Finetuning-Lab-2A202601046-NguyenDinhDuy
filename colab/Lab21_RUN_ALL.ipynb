# %% [markdown]
# # Lab 21 — Fine-tuning LLMs · RUN ALL (T4)
#
# Chay tu tren xuong. Runtime > Change runtime type > **T4 GPU** truoc khi bat dau.
#
# | O | Lam gi | Thoi gian |
# |---|---|---|
# | 1 | clone + install | ~1 phut |
# | 2 | smoke: import + unit test | ~30 giay |
# | 3 | **core pipeline NB1 -> NB5** | ~80 phut |
# | 4 | gatekeeper + in ket qua | ~10 giay |

# %%
# @title 1. Setup — clone + install (chạy ô này trước)
import os, subprocess, sys

REPO = "https://github.com/hieutrungdao/Day21-Track3-Finetuning-Lab.git"
if not os.path.exists("Day21-Track3-Finetuning-Lab"):
    subprocess.run(["git", "clone", "-q", REPO], check=True)
os.chdir("/content/Day21-Track3-Finetuning-Lab")
subprocess.run(["git", "pull", "-q"], check=False)
sys.path.insert(0, "src")

# Install from requirements.txt, NOT a copied list. The copied list is how the
# torchao>=0.16 pin reached requirements.txt and this bootstrap on different days --
# and a bootstrap missing a pin does not fail here, it fails 10 minutes later inside
# get_peft_model(). One source of truth. torch is preinstalled on Colab and
# requirements.txt pins it compatibly, so that line is a no-op.
subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"],
               check=True)

import torch
print("commit :", subprocess.run(["git","rev-parse","--short","HEAD"],
                                 capture_output=True, text=True).stdout.strip())
print("GPU    :", torch.cuda.get_device_name(0) if torch.cuda.is_available()
      else "NONE — Runtime > Change runtime type > T4 GPU")
if torch.cuda.is_available():
    print("VRAM   : %.1f GB" % (torch.cuda.get_device_properties(0).total_memory/1024**3))
# Out:
# commit : 4f619a4
# GPU    : Tesla T4
# VRAM   : 14.6 GB

# %%
# @title 2. Smoke — imports, seed data, unit tests (no GPU needed)
# !python scripts/verify.py --smoke
# Out:
# [  ok  ] labkit imports
# [  ok  ] tier resolves                                    T4 -> unsloth/Qwen3.5-4B
# [  ok  ] all tiers respect the <32 effective-batch rule
# [  ok  ] data/train_seed.jsonl                            250 rows
# [  ok  ] data/eval_target.jsonl                           50 rows
# [  ok  ] data/eval_regression.jsonl                       15 rows
# [ FAIL ] unit tests                                       3 failed, 115 passed in 3.26s
#
# 6 passed · 0 warnings · 1 failures
#
# Not ready to submit — fix the FAILs above.

# %%
# @title 3. Core pipeline — NB1 → NB5
# EVAL_LIMIT truncates both eval sets: "" = full run (submittable),
# 8 = ~fast smoke pass. STAGES lets you resume after a failure.
import os
COMPUTE_TIER = "T4"        # @param ["CPU","LAPTOP","T4","BIGGPU"]
EVAL_LIMIT   = ""         # @param ["", "4", "8", "16", "25"]
STAGES       = "nb1 nb2 nb3 nb4 nb5"   # @param {type:"string"}

os.environ["COMPUTE_TIER"] = COMPUTE_TIER
if EVAL_LIMIT:
    os.environ["EVAL_LIMIT"] = EVAL_LIMIT
else:
    os.environ.pop("EVAL_LIMIT", None)

from labkit import device
print(device.banner(), "\n")

# !python scripts/colab_run.py {STAGES}
# Out:
# Tesla T4 (cuda, sm_75, 14.6 GB) -> precision=fp16
#   note: this GPU predates Ampere, so it has NO bfloat16. Using fp16 with gradient scaling instead. Tutorials that hardcode bf16=True fail here.
#
# tier=T4  mask=assistant-only  eval_limit=8
#
# ========================================================================
# NB1 — data, chat template & loss mask
# ========================================================================
# tier=T4  model=unsloth/Qwen3.5-4B  max_length=1024
# 250 mẫu huấn luyện
# {
#   "instruction": "Phân loại ticket chăm sóc khách hàng sau thành JSON với đúng 4 khóa: intent, urgency, product, sentiment. Chỉ trả về JSON, không giải thích.\n\nintent thuộc: doi_tra | van_chuyen | hoan_tien | san_pham_loi | hoi_thong_tin\nurgency thuộc: cao | trung_binh | thap\nsentiment thuộc: tieu_cuc | trung_tinh | tich_cuc\nproduct: tên sản phẩm xuất hiện trong ticket.",
#   "input": "Alo sh
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 100% 2.76k/2.76k [00:00<00:00, 10.3MB/s]
# tokenizer_config.json: 100% 15.7k/15.7k [00:00<00:00, 20.9MB/s]
# vocab.json: 100% 5.23M/5.23M [00:00<00:00, 116MB/s]
# merges.txt: 100% 3.35M/3.35M [00:00<00:00, 114MB/s]
#
# tokenizer.json: downloading bytes:   2% 381k/20.0M [00:01<01:07, 291kB/s]
# tokenizer.json: downloading bytes: 100% 6.23M/6.23M [00:01<00:00, 4.49MB/s,  605kB/s  ]
# tokenizer.json: reconstructing file: 100% 20.0M/20.0M [00:01<00:00, 14.4MB/s, 1.94MB/s  ]
# added_tokens.json: 100% 904/904 [00:00<00:00, 5.22MB/s]
# special_tokens_map.json: 100% 876/876 [00:00<00:00, 4.43MB/s]
# chat_template.jinja: 100% 7.99k/7.99k [00:00<00:00, 22.0MB/s]
# eos_token: <|im_end|>
# VERDICT: reasoning preserved — safe to train on traces
#
# --- chuỗi đã render ---
# <|im_start|>user
# 2+2?<|im_end|>
# <|im_start|>assistant
# <think>
# buoc 1: kiem tra. buoc 2: tra loi.
# </think>
#
# 4<|im_end|>
#
# ======================================================================
# mode = assistant-only   supervised 39/94 (41%)
# --- LOSS TÍNH TRÊN ĐOẠN NÀY ---
# </think>
#
# {"intent": "doi_tra", "urgency": "trung_binh", "product": "balo laptop", "sentiment": "trung_tinh"}<|im_end|>
#
# ======================================================================
# mode = everything   supervised 94/94 (100%)
# --- LOSS TÍNH TRÊN ĐOẠN NÀY ---
# <|im_start|>system
# Phân loại ticket sau.<|im_end|>
# <|im_start|>user
# Alo shop, mình đặt balo laptop mã đơn VN411453. Cho tôi trả lại. Đã 3 ngày rồi. Cho tôi hỏi.<|im_end|>
# <|im_start|>assistant
# <think>
#
# </think>
#
# {"intent": "doi_tra", "urgency": "trung_binh", "product": "balo laptop", "sentiment": "trung_tinh"}<|im_end|>
#
# {
#   "mask_mode": "assistant-only",
#   "n_supervised": 39,
#   "n_total": 94,
#   "supervised_fraction": 0.4149,
#   "answer_is_supervised": true,
#   "question_is_masked": true
# }
# {
#   "n": 250,
#   "mean": 93.1,
#   "p50": 93,
#   "p95": 98,
#   "p99": 100,
#   "max": 101,
#   "suggested_max_length": 256
# }
#
# ⚠ p95 gợi ý max_length=256 nhưng tier đang đặt 1024. Ghi lại lựa chọn của bạn trong REPORT.md.
# train=225  val=25  -> /content/Day21-Track3-Finetuning-Lab/data/split
#
# -- NB1 ok in 25s
#
# ========================================================================
# NB2 — freeze eval + three baselines
# ========================================================================
# ⚠ EVAL_LIMIT=8 — SMOKE MODE, not a submittable run
# target=8  regression=8  tier=T4
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# model.safetensors.index.json: 100% 76.2k/76.2k [00:00<00:00, 140MB/s]
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files:   0% 0/2 [00:00<?, ?it/s]
# Reconstructing (incomplete total...):   0% 0.00/5.33G [00:00<?, ?B/s]
# Reconstructing (incomplete total...):   0% 0.00/9.32G [00:00<?, ?B/s]
# Downloading bytes:   2% 182M/9.32G [00:02<00:52, 174MB/s,  137MB/s  ]
# Reconstructing (incomplete total...):   1% 67.0M/9.32G [00:02<04:05, 37.7MB/s, 5.24MB/s  ]
# Downloading bytes:   7% 668M/9.32G [00:03<00:26, 328MB/s,  327MB/s  ]
# Downloading bytes:  10% 922M/9.32G [00:04<00:25, 326MB/s,  316MB/s  ]
# Downloading bytes:  11% 996M/9.32G [00:04<00:28, 289MB/s,  280MB/s  ]
# Downloading bytes:  25% 2.33G/9.32G [00:09<00:23, 296MB/s,  289MB/s  ]
# Downloading bytes:  32% 2.96G/9.32G [00:12<00:35, 179MB/s,  221MB/s  ]
# Downloading bytes:  35% 3.28G/9.32G [00:23<00:27, 218MB/s,  177MB/s  ]
# Downloading bytes:  41% 3.86G/9.32G [00:32<00:17, 305MB/s,  325MB/s  ]
# Downloading bytes:  42% 3.93G/9.32G [00:34<01:21, 66.0MB/s, 53.8MB/s  ]
# Downloading bytes:  45% 4.15G/9.32G [00:35<00:24, 213MB/s,  170MB/s  ]
# Downloading bytes:  47% 4.39G/9.32G [00:42<00:43, 113MB/s, 87.4MB/s  ]
# Reconstructing (incomplete total...):  25% 2.36G/9.32G [00:49<02:38, 44.0MB/s, 52.2MB/s  ]
# Downloading bytes:  48% 4.43G/9.32G [00:49<05:49, 14.0MB/s,  113MB/s  ]
# Downloading bytes:  48% 4.50G/9.32G [00:50<03:03, 26.2MB/s, 20.8MB/s  ]
# Downloading bytes:  49% 4.57G/9.32G [00:51<01:36, 49.2MB/s, 44.4MB/s  ]
# Downloading bytes:  50% 4.62G/9.32G [00:52<00:51, 91.4MB/s, 74.8MB/s  ]
# Downloading bytes:  56% 5.25G/9.32G [00:54<00:14, 273MB/s,  273MB/s  ]
# Downloading bytes:  60% 5.59G/9.32G [00:56<00:17, 216MB/s,  193MB/s  ]
# Downloading bytes:  62% 5.79G/9.32G [00:58<00:14, 249MB/s,  247MB/s  ]
# Downloading bytes:  63% 5.87G/9.32G [00:59<00:34, 101MB/s, 88.2MB/s  ]
# Downloading bytes:  69% 6.46G/9.32G [01:02<00:09, 295MB/s,  297MB/s  ]
# Downloading bytes:  70% 6.56G/9.32G [01:03<00:27, 102MB/s, 94.0MB/s  ]
# Downloading bytes:  75% 6.95G/9.32G [01:06<00:13, 182MB/s,  234MB/s  ]
# Reconstructing (incomplete total...):  56% 5.22G/9.32G [01:07<00:33, 121MB/s,  170MB/s  ]
# Downloading bytes:  79% 7.35G/9.32G [01:08<00:09, 210MB/s,  284MB/s  ]
# Reconstructing (incomplete total...):  61% 5.68G/9.32G [01:15<00:52, 68.9MB/s,  172MB/s  ]
# Downloading bytes:  83% 7.74G/9.32G [01:16<00:09, 172MB/s,  172MB/s  ]
# Reconstructing (incomplete total...):  66% 6.13G/9.32G [01:20<00:43, 73.6MB/s,  102MB/s  ]
# Downloading bytes:  86% 8.05G/9.32G [01:21<00:07, 163MB/s,  164MB/s  ]
# Reconstructing (incomplete total...):  71% 6.62G/9.32G [01:23<00:29, 91.9MB/s,  107MB/s  ]
# Reconstructing (incomplete total...):  74% 6.89G/9.32G [01:23<00:18, 131MB/s, 91.9MB/s  ]
# Reconstructing (incomplete total...):  77% 7.17G/9.32G [01:27<00:20, 103MB/s,  131MB/s  ]
# Downloading bytes:  86% 8.05G/9.32G [01:39<00:07, 163MB/s,  163MB/s  ]
# Reconstructing (incomplete total...):  85% 7.96G/9.32G [01:39<00:18, 72.2MB/s, 91.4MB/s  ]
#
# Fetching 2 files:  50% 1/2 [01:39<01:39, 99.97s/it]
# Reconstructing (incomplete total...):  93% 8.64G/9.32G [01:44<00:06, 97.5MB/s, 72.2MB/s  ]
# Reconstructing (incomplete total...):  96% 8.92G/9.32G [01:45<00:03, 114MB/s, 97.5MB/s  ]
# Reconstructing (incomplete total...):  99% 9.18G/9.32G [01:46<00:01, 132MB/s,  114MB/s  ]
# Reconstructing (incomplete total...): 100% 9.28G/9.32G [01:46<00:00, 140MB/s,  132MB/s  ]
# Reconstructing (incomplete total...): 100% 9.32G/9.32G [01:46<00:00, 146MB/s,  140MB/s  ]
#
# Fetching 2 files: 100% 2/2 [01:46<00:00, 53.44s/it]
# Download complete: 100% 8.05G/8.05G [01:46<00:00, 163MB/s,  163MB/s  ]
# Download complete: 100% 8.05G/8.05G [01:47<00:00, 75.2MB/s,  163MB/s  ]
# Reconstruction complete: 100% 9.32G/9.32G [01:47<00:00, 87.1MB/s,  146MB/s  ]
# Loading weights: 100% 426/426 [00:30<00:00, 13.80it/s]
#   [(a) base + naive prompt/target] batch 1/2     14s elapsed  ~   14s left
#   [(a) base + naive prompt/target] batch 2/2     26s elapsed  ~    0s left
#   [(a) base + naive prompt/target] done: 8 prompts in 26s
#   [(a) base + naive prompt/regression] batch 1/2      5s elapsed  ~    5s left
#   [(a) base + naive prompt/regression] batch 2/2     12s elapsed  ~    0s left
#   [(a) base + naive prompt/regression] done: 8 prompts in 12s
# (a) base + naive prompt      target=0.000  regression=0.750  format=0.000  3292ms
#   [(b) base + optimized prompt/target] batch 1/2      4s elapsed  ~    4s left
#   [(b) base + optimized prompt/target] batch 2/2      8s elapsed  ~    0s left
#   [(b) base + optimized prompt/target] done: 8 prompts in 8s
#   [(b) base + optimized prompt/regression] batch 1/2      5s elapsed  ~    5s left
#   [(b) base + optimized prompt/regression] batch 2/2     12s elapsed  ~    0s left
#   [(b) base + optimized prompt/regression] done: 8 prompts in 12s
# (b) base + optimized prompt  target=0.688  regression=0.750  format=1.000  968ms
# {
#   "tier": "T4",
#   "model": "unsloth/Qwen3.5-4B",
#   "baseline_a": {
#     "target": 0.0,
#     "regression": 0.75,
#     "format": 0.0,
#     "latency_ms": 3291.9045792500015,
#     "n": 8,
#     "extra": {}
#   },
#   "baseline_b": {
#     "target": 0.6875,
#     "regression": 0.75,
#     "format": 1.0,
#     "latency_ms": 968.0434103750031,
#     "n": 8,
#     "extra": {}
#   },
#   "optimized_prompt_sha": "719e74d3b6232053",
#   "n_target": 8,
#   "n_regression": 8,
#   "eval_limit": 8,
#   "smoke_mode": true
# }
#
# -- NB2 ok in 214s
#
# ========================================================================
# NB3 — train the correct configuration
# ========================================================================
# T4 · unsloth/Qwen3.5-4B · all-linear · r=16 · LR 10x · 16-bit
# Tesla T4 (cuda, sm_75, 14.6 GB) -> precision=fp16
#   note: this GPU predates Ampere, so it has NO bfloat16. Using fp16 with gradient scaling instead. Tutorials that hardcode bf16=True fail here.
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1022.75it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:33<00:00, 12.77it/s]
# {
#   "num_hidden_layers": 32,
#   "full_attention_interval": 4,
#   "linear_num_key_heads": 16,
#   "layer_types": {
#     "linear_attention": 24,
#     "full_attention": 8
#   }
# }
# placement=text-linear  modules=['down_proj', 'gate_proj', 'in_proj_a', 'in_proj_b', 'in_proj_qkv', 'in_proj_z', 'k_proj', 'o_proj', 'out_proj', 'q_proj', 'up_proj', 'v_proj']
# trainable LoRA params ≈ 32.46 M
#     {'placement': 'text-linear', 'modules': 12, 'r': 16, 'trainable': 32464896}
#     {'placement': 'attn-only(q,v)', 'modules': 2, 'r': 16, 'trainable': 1835008}
#     {'placement': 'attn-only(q,v) matched', 'modules': 2, 'r': 283, 'trainable': 32456704}
# Dataset({
#     features: ['input_ids', 'labels', 'attention_mask'],
#     num_rows: 225
# })
# mask_mode = assistant-only   supervised 9014/20951 tokens (43.0%)
# epochs=2.0  ->  30 optimizer steps  (NB4 runs its contrasts at exactly this many)
# {
#   "output_dir": "/content/Day21-Track3-Finetuning-Lab/adapters/correct",
#   "max_length": "1024",
#   "per_device_train_batch_size": "1",
#   "gradient_accumulation_steps": "16",
#   "learning_rate": "0.0001",
#   "lr_scheduler_type": "cosine",
#   "num_train_epochs": "2.0",
#   "logging_steps": "5",
#   "save_strategy": "no",
#   "report_to": "none",
#   "seed": "42",
#   "packing": "False",
#   "loss_type": "chunked_nll",
#   "gradient_checkpointing": "True",
#   "warmup_steps": "3",
#   "bf16": "False",
#   "fp16": "True",
#   "padding_free": "False"
# }
# Truncating train dataset: 100% 225/225 [00:00<00:00, 7303.53 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 43832.72 examples/s]
# precision fix: {'precision': 'fp16', 'recast': 0, 'trainable_tensors': 496}
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248055}.
# {'loss': '2.163', 'grad_norm': 'nan', 'learning_rate': '9.966e-05', 'entropy': '1.177', 'num_tokens': '7479', 'mean_token_accuracy': '0.6562', 'epoch': '0.3556'}
# {'loss': '1.38', 'grad_norm': '2.523', 'learning_rate': '8.83e-05', 'entropy': '1.033', 'num_tokens': '1.49e+04', 'mean_token_accuracy': '0.7697', 'epoch': '0.7111'}
# {'loss': '0.1392', 'grad_norm': '0.6282', 'learning_rate': '6.434e-05', 'entropy': '0.2644', 'num_tokens': '2.095e+04', 'mean_token_accuracy': '0.9587', 'epoch': '1'}
# {'loss': '0.02983', 'grad_norm': '0.8732', 'learning_rate': '3.566e-05', 'entropy': '0.04243', 'num_tokens': '2.843e+04', 'mean_token_accuracy': '0.9876', 'epoch': '1.356'}
# {'loss': '0.01816', 'grad_norm': '0.266', 'learning_rate': '1.17e-05', 'entropy': '0.02266', 'num_tokens': '3.59e+04', 'mean_token_accuracy': '0.9934', 'epoch': '1.711'}
# {'loss': '0.02484', 'grad_norm': 'nan', 'learning_rate': '3.381e-07', 'entropy': '0.01679', 'num_tokens': '4.19e+04', 'mean_token_accuracy': '0.9965', 'epoch': '2'}
# {'train_runtime': '933.7', 'train_samples_per_second': '0.482', 'train_steps_per_second': '0.032', 'train_loss': '0.6259', 'epoch': '2'}
# 100% 30/30 [15:33<00:00, 31.12s/it]
# train 934s  final loss 0.6259
# saved -> /content/Day21-Track3-Finetuning-Lab/adapters/correct
# {
#   "run": "correct",
#   "label": "all-linear · r=16 · LR 10x · 16-bit",
#   "tier": "T4",
#   "model": "unsloth/Qwen3.5-4B",
#   "precision": "fp16",
#   "placement": "text-linear",
#   "n_target_modules": 12,
#   "r": 16,
#   "lora_alpha": 32,
#   "learning_rate": 0.0001,
#   "load_in_4bit": false,
#   "trainable_params": 32464896,
#   "train_seconds": 934.2,
#   "peak_vram_gb": 12.01,
#   "final_loss": 0.6259,
#   "mask_mode": "assistant-only",
#   "max_steps": 30
# }
#
# -- NB3 ok in 998s
#
# ========================================================================
# NB4 — three misconfiguration contrasts
# ========================================================================
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1022.25it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:33<00:00, 12.83it/s]
# | placement | modules | r | trainable |
# |---|---|---|---|
# | text-linear | 12 | 16 | 32464896 |
# | attn-only(q,v) | 2 | 16 | 1835008 |
# | attn-only(q,v) matched | 2 | 283 | 32456704 |
# ======================================================================
# RUN attn_only: q,v only · r=matched · LR 10x · 16-bit
#      Mistake #1 (§10.2): attention-only placement, rank raised to *match parameter count*. If rank were the lever, this would win.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 937.80it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:32<00:00, 12.92it/s]
#   train_ds: Dataset({
#     features: ['input_ids', 'labels', 'attention_mask'],
#     num_rows: 225
# })
#   matched rank for attn_only: r=283 (alpha=566)
# Truncating train dataset: 100% 225/225 [00:00<00:00, 5869.48 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 27189.44 examples/s]
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248055}.
# {'loss': '2.163', 'grad_norm': '5.738', 'learning_rate': '9.966e-05', 'entropy': '1.177', 'num_tokens': '7479', 'mean_token_accuracy': '0.6562', 'epoch': '0.3556'}
# {'loss': '0.8313', 'grad_norm': '1.833', 'learning_rate': '8.83e-05', 'entropy': '0.9433', 'num_tokens': '1.49e+04', 'mean_token_accuracy': '0.8406', 'epoch': '0.7111'}
# {'loss': '0.1485', 'grad_norm': '1.461', 'learning_rate': '6.434e-05', 'entropy': '0.2872', 'num_tokens': '2.095e+04', 'mean_token_accuracy': '0.9572', 'epoch': '1'}
# {'loss': '0.04006', 'grad_norm': '0.8561', 'learning_rate': '3.566e-05', 'entropy': '0.06518', 'num_tokens': '2.843e+04', 'mean_token_accuracy': '0.9867', 'epoch': '1.356'}
# {'loss': '0.02223', 'grad_norm': '0.2048', 'learning_rate': '1.17e-05', 'entropy': '0.03184', 'num_tokens': '3.59e+04', 'mean_token_accuracy': '0.9912', 'epoch': '1.711'}
# {'loss': '0.02567', 'grad_norm': 'nan', 'learning_rate': '3.381e-07', 'entropy': '0.02324', 'num_tokens': '4.19e+04', 'mean_token_accuracy': '0.9945', 'epoch': '2'}
# {'train_runtime': '792.8', 'train_samples_per_second': '0.605', 'train_steps_per_second': '0.038', 'train_loss': '0.5385', 'epoch': '2'}
# 100% 30/30 [13:12<00:00, 26.43s/it]
# ======================================================================
# RUN wrong_lr: all-linear · r=16 · LR 1x (full-FT scale) · 16-bit
#      Mistake #2 (§10.3): a full-fine-tune learning rate applied to LoRA.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1295.54it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:33<00:00, 12.72it/s]
# Truncating train dataset: 100% 225/225 [00:00<00:00, 8678.67 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 34344.51 examples/s]
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248055}.
# {'loss': '2.163', 'grad_norm': 'nan', 'learning_rate': '9.966e-06', 'entropy': '1.177', 'num_tokens': '7479', 'mean_token_accuracy': '0.6562', 'epoch': '0.3556'}
# {'loss': '2.066', 'grad_norm': '5.105', 'learning_rate': '8.83e-06', 'entropy': '1.199', 'num_tokens': '1.49e+04', 'mean_token_accuracy': '0.6793', 'epoch': '0.7111'}
# {'loss': '1.606', 'grad_norm': 'nan', 'learning_rate': '6.434e-06', 'entropy': '1.178', 'num_tokens': '2.095e+04', 'mean_token_accuracy': '0.7176', 'epoch': '1'}
# {'loss': '1.326', 'grad_norm': '4.63', 'learning_rate': '3.566e-06', 'entropy': '1.103', 'num_tokens': '2.843e+04', 'mean_token_accuracy': '0.7564', 'epoch': '1.356'}
# {'loss': '1.141', 'grad_norm': '4.213', 'learning_rate': '1.17e-06', 'entropy': '1.077', 'num_tokens': '3.59e+04', 'mean_token_accuracy': '0.7979', 'epoch': '1.711'}
# {'loss': '1.119', 'grad_norm': 'nan', 'learning_rate': '3.381e-08', 'entropy': '1.069', 'num_tokens': '4.19e+04', 'mean_token_accuracy': '0.7905', 'epoch': '2'}
# {'train_runtime': '917.7', 'train_samples_per_second': '0.523', 'train_steps_per_second': '0.033', 'train_loss': '1.57', 'epoch': '2'}
# 100% 30/30 [15:17<00:00, 30.59s/it]
# ======================================================================
# RUN qlora: all-linear · r=16 · LR 10x · 4-bit QLoRA
#      The vendor says do NOT use QLoRA on Qwen3.5 (§12). Measure the cost yourself instead of taking either side on faith.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 997.69it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:34<00:00, 12.50it/s]
# Truncating train dataset: 100% 225/225 [00:00<00:00, 9742.11 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 46224.45 examples/s]
#   precision fix: recast 496/496 trainable tensors bf16 -> fp32 for the fp16 GradScaler
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248055}.
# {'loss': '2.155', 'grad_norm': 'nan', 'learning_rate': '9.966e-05', 'entropy': '1.34', 'num_tokens': '7479', 'mean_token_accuracy': '0.656', 'epoch': '0.3556'}
# {'loss': '1.731', 'grad_norm': '3.368', 'learning_rate': '8.83e-05', 'entropy': '1.287', 'num_tokens': '1.49e+04', 'mean_token_accuracy': '0.7214', 'epoch': '0.7111'}
# {'loss': '0.2408', 'grad_norm': '1.019', 'learning_rate': '6.434e-05', 'entropy': '0.3825', 'num_tokens': '2.095e+04', 'mean_token_accuracy': '0.9382', 'epoch': '1'}
# {'loss': '0.0513', 'grad_norm': '1.023', 'learning_rate': '3.566e-05', 'entropy': '0.07534', 'num_tokens': '2.843e+04', 'mean_token_accuracy': '0.9829', 'epoch': '1.356'}
# {'loss': '0.03019', 'grad_norm': '0.3238', 'learning_rate': '1.17e-05', 'entropy': '0.0355', 'num_tokens': '3.59e+04', 'mean_token_accuracy': '0.9884', 'epoch': '1.711'}
# {'loss': '0.02674', 'grad_norm': '3.368', 'learning_rate': '3.381e-07', 'entropy': '0.03056', 'num_tokens': '4.19e+04', 'mean_token_accuracy': '0.992', 'epoch': '2'}
# {'train_runtime': '985.4', 'train_samples_per_second': '0.487', 'train_steps_per_second': '0.03', 'train_loss': '0.7058', 'epoch': '2'}
# 100% 30/30 [16:25<00:00, 32.85s/it]
# | run | label | r | trainable_params | learning_rate | final_loss | train_seconds | peak_vram_gb |
# |---|---|---|---|---|---|---|---|
# | correct | all-linear · r=16 · LR 10x · 16-bit | 16 | 32464896 | 0.0001 | 0.6259 | 934.2 | 12.01 |
# | attn_only | q,v only · r=matched · LR 10x · 16-bit | 283 | 32456704 | 0.0001 | 0.5385 | 793.2 | 12.02 |
# | wrong_lr | all-linear · r=16 · LR 1x (full-FT scale) · 16-bit | 16 | 32464896 | 1e-05 | 1.5704 | 918.1 | 12.01 |
# | qlora | all-linear · r=16 · LR 10x · 4-bit QLoRA | 16 | 32464896 | 0.0001 | 0.7058 | 985.8 | 7.09 |
#
# -- NB4 ok in 2878s
#
# ========================================================================
# NB5 — four-group eval + verdict
# ========================================================================
# baseline (b) target = 0.688 — đây là mốc phải vượt
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 847.85it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:34<00:00, 12.53it/s]
#   [ft/target] batch 1/2      6s elapsed  ~    6s left
#   [ft/target] batch 2/2     12s elapsed  ~    0s left
#   [ft/target] done: 8 prompts in 12s
#   [ft/regression] batch 1/2      8s elapsed  ~    8s left
#   [ft/regression] batch 2/2     19s elapsed  ~    0s left
#   [ft/regression] done: 8 prompts in 19s
# fine-tune: {'target': 0.9375, 'regression': 0.75, 'format': 1.0, 'latency_ms': 1541.57739974994, 'n': 8, 'extra': {'valid_trace_rate': 0.0}}
# | run | target | regression | format | latency_ms | n |
# |---|---|---|---|---|---|
# | (a) base + naive prompt | 0.0 | 0.75 | 0.0 | 3291.9 | 8 |
# | (b) base + optimized prompt | 0.6875 | 0.75 | 1.0 | 968.0 | 8 |
# | (c) LoRA fine-tune | 0.9375 | 0.75 | 1.0 | 1541.6 | 8 |
# PASSED
#  - beat the optimized-prompt baseline by +0.250 with +0.000 general-capability change.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1034.61it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:33<00:00, 12.59it/s]
#   [attn_only/target] batch 1/2      3s elapsed  ~    3s left
#   [attn_only/target] batch 2/2      7s elapsed  ~    0s left
#   [attn_only/target] done: 8 prompts in 7s
# attn_only: target=0.938  format=1.000
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 891.65it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:33<00:00, 12.76it/s]
#   [wrong_lr/target] batch 1/2     19s elapsed  ~   19s left
#   [wrong_lr/target] batch 2/2     39s elapsed  ~    0s left
#   [wrong_lr/target] done: 8 prompts in 39s
# wrong_lr: target=0.000  format=0.000
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 921.83it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:35<00:00, 12.01it/s]
#   [qlora/target] batch 1/2      7s elapsed  ~    7s left
#   [qlora/target] batch 2/2     14s elapsed  ~    0s left
#   [qlora/target] done: 8 prompts in 14s
# qlora: target=0.844  format=1.000
#
# | run | target | format | latency_ms | n |
# |---|---|---|---|---|
# | correct | 0.9375 | 1.0 | 1541.6 | 8 |
# | attn_only | 0.9375 | 1.0 | 833.2 | 8 |
# | wrong_lr | 0.0 | 0.0 | 4854.4 | 8 |
# | qlora | 0.8438 | 1.0 | 1736.9 | 8 |
# --- 3 ca TỆ NHẤT (bắt buộc đưa vào report) ---
# | i | ticket | ft_score | ft_pred |
# |---|---|---|---|
# | 3 | Cho mình hỏi, mình đặt bình giữ nhiệt mã đơn VN804124. Chưa thấy tiền. | 0.75 | {"intent": "hoan_tien", "urgency": "trung_binh", "product": "bình giữ nhiệt", "sentiment": |
# | 5 | Shop ơi, mình đặt nồi chiên không dầu mã đơn DH249548. Thiếu phụ kiện. | 0.75 | {"intent": "san_pham_loi", "urgency": "trung_binh", "product": "nồi chiên không dầu", "sen |
# | 0 | Cho mình hỏi, mình đặt chuột không dây mã đơn VN232232. Cho tôi trả lạ | 1.0 | {"intent": "doi_tra", "urgency": "cao", "product": "chuột không dây", "sentiment": "tich_c |
#
# --- 3 ca TỐT NHẤT ---
# | i | ticket | ft_score | ft_pred |
# |---|---|---|---|
# | 4 | Cho mình hỏi, mình đặt đèn bàn LED mã đơn VN339109. Vỡ khi nhận. Gấp.  | 1.0 | {"intent": "san_pham_loi", "urgency": "cao", "product": "đèn bàn LED", "sentiment": "trung |
# | 6 | Xin chào, mình đặt balo laptop mã đơn DH863123. Đổi size. Hỏi cho biết | 1.0 | {"intent": "doi_tra", "urgency": "thap", "product": "balo laptop", "sentiment": "tieu_cuc" |
# | 7 | Alo shop, mình đặt máy xay sinh tố mã đơn OD126693. Muốn đổi. Đã 3 ngà | 1.0 | {"intent": "doi_tra", "urgency": "trung_binh", "product": "máy xay sinh tố", "sentiment":  |
#
# -- NB5 ok in 273s
#
# ----------------------------------------
# stage timings
#   nb1        25s  (0.4 min)
#   nb2       214s  (3.6 min)
#   nb3       998s  (16.6 min)
#   nb4      2878s  (48.0 min)
#   nb5       273s  (4.5 min)
#   total    4388s (73.1 min)

# %%
# @title 4. Gatekeeper + results
# !python scripts/verify.py
print("\n================ results/ ================")
# !ls -la results/
# !echo && echo "---- runs.csv ----" && cat results/runs.csv 2>/dev/null
# !echo && echo "---- verdict.json ----" && cat results/verdict.json 2>/dev/null
# Out:
# [  ok  ] labkit imports
# [  ok  ] tier resolves                                    T4 -> unsloth/Qwen3.5-4B
# [  ok  ] all tiers respect the <32 effective-batch rule
# [  ok  ] data/train_seed.jsonl                            250 rows
# [  ok  ] data/eval_target.jsonl                           50 rows
# [  ok  ] data/eval_regression.jsonl                       15 rows
# [ FAIL ] unit tests                                       3 failed, 115 passed in 2.79s
# [  ok  ] results/template_check.json
# [  ok  ] results/mask_proof.json
# [  ok  ] results/token_stats.json
# [  ok  ] results/baselines_frozen.json
# [  ok  ] results/runs.csv
# [  ok  ] results/verdict.json
# [  ok  ] results/autopsy.json
# [  ok  ] submission/REPORT.md
# [ FAIL ] REPORT.md filled in                              6 placeholders still present (<điền>, <paste>, ...) — this is still the template
# [  ok  ] mask proof asserts
# [ FAIL ] full eval set used                               EVAL_LIMIT=8 — this run scored 8 target items, not the full set. Smoke mode is for iterating; unset EVAL_LIMIT and re-run NB2+NB5 to submit.
# [  ok  ] baseline (b) prompt unmodified
# [  ok  ] baseline (b) beats (a)                           (a)=0.000 -> (b)=0.688
# [  ok  ] eval sets unmodified
# [  ok  ] NB3 run present
# [  ok  ] NB4 contrast runs
# [  ok  ] all runs share ONE step budget                   ['attn_only', 'correct', 'qlora', 'wrong_lr'] at 30 steps
# [  ok  ] attn_only is a FAIR contrast                     32,456,704 vs 32,464,896 trainable params
# [  ok  ] verdict recorded                                 PASSED (target Δ +0.250, regression Δ +0.000)
#
# 23 passed · 0 warnings · 3 failures
#
# Not ready to submit — fix the FAILs above.
#
# ================ results/ ================
# total 40
# drwxr-xr-x  2 root root 4096 Aug 21 10:12 .
# drwxr-xr-x 15 root root 4096 Aug 21 08:59 ..
# -rw-r--r--  1 root root  435 Aug 21 10:12 autopsy.json
# -rw-r--r--  1 root root  480 Aug 21 09:03 baselines_frozen.json
# -rw-r--r--  1 root root    0 Aug 21 08:59 .gitkeep
# -rw-r--r--  1 root root  592 Aug 21 08:59 mask_proof.json
# -rw-r--r--  1 root root 2206 Aug 21 10:12 qualitative.json
# -rw-r--r--  1 root root 1099 Aug 21 10:08 runs.csv
# -rw-r--r--  1 root root  277 Aug 21 08:59 template_check.json
# -rw-r--r--  1 root root  115 Aug 21 08:59 token_stats.json
# -rw-r--r--  1 root root  751 Aug 21 10:09 verdict.json
#
# ---- runs.csv ----
# run,label,tier,model,precision,placement,n_target_modules,r,lora_alpha,learning_rate,load_in_4bit,trainable_params,train_seconds,peak_vram_gb,final_loss,mask_mode,max_steps,teaches
# correct,all-linear · r=16 · LR 10x · 16-bit,T4,unsloth/Qwen3.5-4B,fp16,text-linear,12,16,32,0.0001,False,32464896,934.2,12.01,0.6259,assistant-only,30,
# attn_only,"q,v only · r=matched · LR 10x · 16-bit",T4,unsloth/Qwen3.5-4B,fp16,attn-only,2,283,566,0.0001,False,32456704,793.2,12.02,0.5385,,30,"Mistake #1 (§10.2): attention-only placement, rank raised to *match parameter count*. If rank were the lever, this would win."
# wrong_lr,all-linear · r=16 · LR 1x (full-FT scale) · 16-bit,T4,unsloth/Qwen3.5-4B,fp16,text-linear,12,16,32,1e-05,False,32464896,918.1,12.01,1.5704,,30,Mistake #2 (§10.3): a full-fine-tune learning rate applied to LoRA.
# qlora,all-linear · r=16 · LR 10x · 4-bit QLoRA,T4,unsloth/Qwen3.5-4B,fp16,text-linear,12,16,32,0.0001,True,32464896,985.8,7.09,0.7058,,30,The vendor says do NOT use QLoRA on Qwen3.5 (§12). Measure the cost yourself instead of taking either side on faith.
#
# ---- verdict.json ----
# {
#   "comparison": [
#     {
#       "run": "(a) base + naive prompt",
#       "target": 0.0,
#       "regression": 0.75,
#       "format": 0.0,
#       "latency_ms": 3291.9,
#       "n": 8
#     },
#     {
#       "run": "(b) base + optimized prompt",
#       "target": 0.6875,
#       "regression": 0.75,
#       "format": 1.0,
#       "latency_ms": 968.0,
#       "n": 8
#     },
#     {
#       "run": "(c) LoRA fine-tune",
#       "target": 0.9375,
#       "regression": 0.75,
#       "format": 1.0,
#       "latency_ms": 1541.6,
#       "n": 8
#     }
#   ],
#   "verdict": {
#     "passed": true,
#     "reasons": [
#       "beat the optimized-prompt baseline by +0.250 with +0.000 general-capability change."
#     ],
#     "target_delta": 0.25,
#     "regression_delta": 0.0
#   },
#   "valid_trace_rate": 0.0
# }

# %%
# !EVAL_LIMIT=0 python notebooks/02_baselines.py
# !EVAL_LIMIT=0 python notebooks/05_evaluate_and_verdict.py
# Out:
# target=50  regression=15  tier=T4
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 919.90it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:33<00:00, 12.61it/s]
#   [(a) base + naive prompt/target] batch 1/13     13s elapsed  ~  160s left
#   [(a) base + naive prompt/target] batch 2/13     26s elapsed  ~  141s left
#   [(a) base + naive prompt/target] batch 3/13     38s elapsed  ~  126s left
#   [(a) base + naive prompt/target] batch 4/13     49s elapsed  ~  111s left
#   [(a) base + naive prompt/target] batch 5/13     62s elapsed  ~   99s left
#   [(a) base + naive prompt/target] batch 6/13     74s elapsed  ~   86s left
#   [(a) base + naive prompt/target] batch 7/13     86s elapsed  ~   73s left
#   [(a) base + naive prompt/target] batch 8/13     98s elapsed  ~   61s left
#   [(a) base + naive prompt/target] batch 9/13    110s elapsed  ~   49s left
#   [(a) base + naive prompt/target] batch 10/13    122s elapsed  ~   36s left
#   [(a) base + naive prompt/target] batch 11/13    134s elapsed  ~   24s left
#   [(a) base + naive prompt/target] batch 12/13    146s elapsed  ~   12s left
#   [(a) base + naive prompt/target] batch 13/13    158s elapsed  ~    0s left
#   [(a) base + naive prompt/target] done: 50 prompts in 158s
#   [(a) base + naive prompt/regression] batch 1/4      5s elapsed  ~   15s left
#   [(a) base + naive prompt/regression] batch 2/4     13s elapsed  ~   13s left
#   [(a) base + naive prompt/regression] batch 3/4     20s elapsed  ~    7s left
#   [(a) base + naive prompt/regression] batch 4/4     28s elapsed  ~    0s left
#   [(a) base + naive prompt/regression] done: 15 prompts in 28s
# (a) base + naive prompt      target=0.000  regression=0.758  format=0.000  3158ms
#   [(b) base + optimized prompt/target] batch 1/13      4s elapsed  ~   48s left
#   [(b) base + optimized prompt/target] batch 2/13      8s elapsed  ~   45s left
#   [(b) base + optimized prompt/target] batch 3/13     12s elapsed  ~   39s left
#   [(b) base + optimized prompt/target] batch 4/13     15s elapsed  ~   34s left
#   [(b) base + optimized prompt/target] batch 5/13     20s elapsed  ~   32s left
#   [(b) base + optimized prompt/target] batch 6/13     24s elapsed  ~   27s left
#   [(b) base + optimized prompt/target] batch 7/13     27s elapsed  ~   23s left
#   [(b) base + optimized prompt/target] batch 8/13     31s elapsed  ~   19s left
#   [(b) base + optimized prompt/target] batch 9/13     35s elapsed  ~   16s left
#   [(b) base + optimized prompt/target] batch 10/13     38s elapsed  ~   12s left
#   [(b) base + optimized prompt/target] batch 11/13     42s elapsed  ~    8s left
#   [(b) base + optimized prompt/target] batch 12/13     46s elapsed  ~    4s left
#   [(b) base + optimized prompt/target] batch 13/13     49s elapsed  ~    0s left
#   [(b) base + optimized prompt/target] done: 50 prompts in 49s
#   [(b) base + optimized prompt/regression] batch 1/4      5s elapsed  ~   15s left
#   [(b) base + optimized prompt/regression] batch 2/4     12s elapsed  ~   12s left
#   [(b) base + optimized prompt/regression] batch 3/4     20s elapsed  ~    7s left
#   [(b) base + optimized prompt/regression] batch 4/4     27s elapsed  ~    0s left
#   [(b) base + optimized prompt/regression] done: 15 prompts in 27s
# (b) base + optimized prompt  target=0.765  regression=0.758  format=1.000  989ms
# {
#   "tier": "T4",
#   "model": "unsloth/Qwen3.5-4B",
#   "baseline_a": {
#     "target": 0.0,
#     "regression": 0.7577777777777778,
#     "format": 0.0,
#     "latency_ms": 3157.7096848200017,
#     "n": 50,
#     "extra": {}
#   },
#   "baseline_b": {
#     "target": 0.765,
#     "regression": 0.7577777777777778,
#     "format": 1.0,
#     "latency_ms": 988.5064276400226,
#     "n": 50,
#     "extra": {}
#   },
#   "optimized_prompt_sha": "719e74d3b6232053",
#   "n_target": 50,
#   "n_regression": 15,
#   "eval_limit": null,
#   "smoke_mode": false
# }
# baseline (b) target = 0.765 — đây là mốc phải vượt
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 951.31it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:33<00:00, 12.69it/s]
#   [ft/target] batch 1/13      6s elapsed  ~   72s left
#   [ft/target] batch 2/13     12s elapsed  ~   66s left
#   [ft/target] batch 3/13     17s elapsed  ~   56s left
#   [ft/target] batch 4/13     22s elapsed  ~   49s left
#   [ft/target] batch 5/13     28s elapsed  ~   44s left
#   [ft/target] batch 6/13     33s elapsed  ~   38s left
#   [ft/target] batch 7/13     38s elapsed  ~   33s left
#   [ft/target] batch 8/13     43s elapsed  ~   27s left
#   [ft/target] batch 9/13     48s elapsed  ~   21s left
#   [ft/target] batch 10/13     54s elapsed  ~   16s left
#   [ft/target] batch 11/13     58s elapsed  ~   11s left
#   [ft/target] batch 12/13     64s elapsed  ~    5s left
#   [ft/target] batch 13/13     70s elapsed  ~    0s left
#   [ft/target] done: 50 prompts in 70s
#   [ft/regression] batch 1/4      9s elapsed  ~   27s left
#   [ft/regression] batch 2/4     20s elapsed  ~   20s left
#   [ft/regression] batch 3/4     26s elapsed  ~    9s left
#   [ft/regression] batch 4/4     38s elapsed  ~    0s left
#   [ft/regression] done: 15 prompts in 38s
# fine-tune: {'target': 0.965, 'regression': 0.6777777777777777, 'format': 1.0, 'latency_ms': 1389.6271774600061, 'n': 50, 'extra': {'valid_trace_rate': 0.0}}
# | run | target | regression | format | latency_ms | n |
# |---|---|---|---|---|---|
# | (a) base + naive prompt | 0.0 | 0.7578 | 0.0 | 3157.7 | 50 |
# | (b) base + optimized prompt | 0.765 | 0.7578 | 1.0 | 988.5 | 50 |
# | (c) LoRA fine-tune | 0.965 | 0.6778 | 1.0 | 1389.6 | 50 |
# FAILED
#  - general capability regressed by 0.080 (tolerance 0.020). See deck §14.3 — add 1-5% replay data.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1030.16it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:33<00:00, 12.87it/s]
#   [attn_only/target] batch 1/13      4s elapsed  ~   42s left
#   [attn_only/target] batch 2/13      7s elapsed  ~   38s left
#   [attn_only/target] batch 3/13     10s elapsed  ~   34s left
#   [attn_only/target] batch 4/13     14s elapsed  ~   31s left
#   [attn_only/target] batch 5/13     17s elapsed  ~   28s left
#   [attn_only/target] batch 6/13     21s elapsed  ~   24s left
#   [attn_only/target] batch 7/13     24s elapsed  ~   20s left
#   [attn_only/target] batch 8/13     28s elapsed  ~   17s left
#   [attn_only/target] batch 9/13     31s elapsed  ~   14s left
#   [attn_only/target] batch 10/13     34s elapsed  ~   10s left
#   [attn_only/target] batch 11/13     38s elapsed  ~    7s left
#   [attn_only/target] batch 12/13     41s elapsed  ~    3s left
#   [attn_only/target] batch 13/13     44s elapsed  ~    0s left
#   [attn_only/target] done: 50 prompts in 44s
# attn_only: target=0.965  format=1.000
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1278.75it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:33<00:00, 12.76it/s]
#   [wrong_lr/target] batch 1/13     20s elapsed  ~  238s left
#   [wrong_lr/target] batch 2/13     39s elapsed  ~  216s left
#   [wrong_lr/target] batch 3/13     59s elapsed  ~  195s left
#   [wrong_lr/target] batch 4/13     78s elapsed  ~  176s left
#   [wrong_lr/target] batch 5/13     98s elapsed  ~  156s left
#   [wrong_lr/target] batch 6/13    118s elapsed  ~  137s left
#   [wrong_lr/target] batch 7/13    137s elapsed  ~  117s left
#   [wrong_lr/target] batch 8/13    156s elapsed  ~   98s left
#   [wrong_lr/target] batch 9/13    175s elapsed  ~   78s left
#   [wrong_lr/target] batch 10/13    195s elapsed  ~   59s left
#   [wrong_lr/target] batch 11/13    215s elapsed  ~   39s left
#   [wrong_lr/target] batch 12/13    234s elapsed  ~   19s left
#   [wrong_lr/target] batch 13/13    253s elapsed  ~    0s left
#   [wrong_lr/target] done: 50 prompts in 253s
# wrong_lr: target=0.000  format=0.000
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 953.79it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:34<00:00, 12.19it/s]
#   [qlora/target] batch 1/13      7s elapsed  ~   87s left
#   [qlora/target] batch 2/13     14s elapsed  ~   77s left
#   [qlora/target] batch 3/13     21s elapsed  ~   70s left
#   [qlora/target] batch 4/13     27s elapsed  ~   62s left
#   [qlora/target] batch 5/13     34s elapsed  ~   55s left
#   [qlora/target] batch 6/13     41s elapsed  ~   47s left
#   [qlora/target] batch 7/13     47s elapsed  ~   41s left
#   [qlora/target] batch 8/13     53s elapsed  ~   33s left
#   [qlora/target] batch 9/13     61s elapsed  ~   27s left
#   [qlora/target] batch 10/13     67s elapsed  ~   20s left
#   [qlora/target] batch 11/13     74s elapsed  ~   13s left
#   [qlora/target] batch 12/13     81s elapsed  ~    7s left
#   [qlora/target] batch 13/13     88s elapsed  ~    0s left
#   [qlora/target] done: 50 prompts in 88s
# qlora: target=0.940  format=1.000
#
# | run | target | format | latency_ms | n |
# |---|---|---|---|---|
# | correct | 0.965 | 1.0 | 1389.6 | 50 |
# | attn_only | 0.965 | 1.0 | 887.1 | 50 |
# | wrong_lr | 0.0 | 0.0 | 5062.8 | 50 |
# | qlora | 0.94 | 1.0 | 1750.8 | 50 |
# --- 3 ca TỆ NHẤT (bắt buộc đưa vào report) ---
# | i | ticket | ft_score | ft_pred |
# |---|---|---|---|
# | 3 | Cho mình hỏi, mình đặt bình giữ nhiệt mã đơn VN804124. Chưa thấy tiền. | 0.75 | {"intent": "hoan_tien", "urgency": "trung_binh", "product": "bình giữ nhiệt", "sentiment": |
# | 5 | Shop ơi, mình đặt nồi chiên không dầu mã đơn DH249548. Thiếu phụ kiện. | 0.75 | {"intent": "san_pham_loi", "urgency": "trung_binh", "product": "nồi chiên không dầu", "sen |
# | 12 | Shop ơi, mình đặt áo khoác gió mã đơn VN613097. Bị lỗi. Khi nào tiện.  | 0.75 | {"intent": "san_pham_loi", "urgency": "trung_binh", "product": "áo khoác gió", "sentiment" |
#
# --- 3 ca TỐT NHẤT ---
# | i | ticket | ft_score | ft_pred |
# |---|---|---|---|
# | 47 | Cho mình hỏi, mình đặt ốp lưng điện thoại mã đơn DH936478. Shipper khô | 1.0 | {"intent": "van_chuyen", "urgency": "thap", "product": "ốp lưng điện thoại", "sentiment":  |
# | 48 | Alo shop, mình đặt ốp lưng điện thoại mã đơn DH734695. Giá bao nhiêu.  | 1.0 | {"intent": "hoi_thong_tin", "urgency": "trung_binh", "product": "ốp lưng điện thoại", "sen |
# | 49 | Chào shop, mình đặt ốp lưng điện thoại mã đơn VN833689. Sai màu. Sớm n | 1.0 | {"intent": "san_pham_loi", "urgency": "trung_binh", "product": "ốp lưng điện thoại", "sent |

# %%
import shutil
from google.colab import files

# 1. Nén toàn bộ thư mục results và adapter
# !zip -r results.zip results/
# !zip -r adapters_correct.zip adapters/correct/

# 2. Tự động bật cửa sổ tải về máy tính
files.download("results.zip")
files.download("adapters_correct.zip")
# Out:
# updating: results/ (stored 0%)
# updating: results/runs.csv (deflated 47%)
# updating: results/token_stats.json (deflated 34%)
# updating: results/.gitkeep (stored 0%)
# updating: results/mask_proof.json (deflated 42%)
# updating: results/template_check.json (deflated 36%)
# updating: results/autopsy.json (deflated 67%)
# updating: results/qualitative.json (deflated 86%)
# updating: results/verdict.json (deflated 57%)
# updating: results/baselines_frozen.json (deflated 52%)
# updating: adapters/correct/ (stored 0%)
# updating: adapters/correct/chat_template.jinja (deflated 76%)
# updating: adapters/correct/adapter_config.json (deflated 62%)
# updating: adapters/correct/tokenizer_config.json (deflated 65%)
# updating: adapters/correct/tokenizer.json (deflated 80%)
# updating: adapters/correct/adapter_model.safetensors (deflated 8%)
# updating: adapters/correct/README.md (deflated 65%)
